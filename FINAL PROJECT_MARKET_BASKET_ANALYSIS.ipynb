# %% [markdown]
# ##  1) EXPLORATORY DATA ANALYSIS and VISUALIZATION:

# %% [markdown]
# ### Let's import the libraries:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from mlxtend.frequent_patterns import apriori,association_rules
from collections import Counter

# %% [markdown]
# ### Reading the dataset:

# %%
dataset = pd.read_excel("Online Retail.xlsx")
dataset
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ### Let's see the dimension of the dataset:

# %%
dataset.shape
# Out:
# (541909, 8)

# %% [markdown]
# ### Let's verify missing values:

# %%
dataset.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# #### There are many missing values on the Description and CustomerID Columns.

# %% [markdown]
# ### Let's remove them:

# %%
dataset1 = dataset.dropna()
dataset1.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  406829.000000  406829.000000  406829.000000
# mean       12.061303       3.460471   15287.690570
# std       248.693370      69.315162    1713.600303
# min    -80995.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13953.000000
# 50%         5.000000       1.950000   15152.000000
# 75%        12.000000       3.750000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# #### Quantity contains some negative values, which indicates inaccurate data. Thus we will remove such entries.

# %%
dataset1.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
#selecting data where quantity > 0
dataset1= dataset1[dataset1.Quantity > 0]
dataset1.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  397924.000000  397924.000000  397924.000000
# mean       13.021823       3.116174   15294.315171
# std       180.420210      22.096788    1713.169877
# min         1.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13969.000000
# 50%         6.000000       1.950000   15159.000000
# 75%        12.000000       3.750000   16795.000000
# max     80995.000000    8142.750000   18287.000000

# %% [markdown]
# ## Customers Insight From Dataset:

# %% [markdown]
# ### Let's get the top customers with the most number of orders:

# %%
# Creating a new feature 'Amount' which is the product of Quantity and its Unit Price

dataset1['Amount'] = dataset1['Quantity'] * dataset1['UnitPrice']

# to highlight the Customers with most no. of orders (invoices) with groupby function

orders = dataset1.groupby(by=['CustomerID','Country'], as_index=False)['InvoiceNo'].count()
print('The TOP 5 loyal customers with most number of orders...')
orders.sort_values(by='InvoiceNo', ascending=False).head()
# Out:
# The TOP 5 loyal customers with most number of orders...
#       CustomerID         Country  InvoiceNo
# 4019     17841.0  United Kingdom       7847
# 1888     14911.0            EIRE       5677
# 1298     14096.0  United Kingdom       5111
# 334      12748.0  United Kingdom       4596
# 1670     14606.0  United Kingdom       2700

# %% [markdown]
# #### We can observe the top 5 loyal customers with the most orders in above table.

# %% [markdown]
# ### The below code plots the number of orders by different customers:

# %%
# Creating a subplot of size 15x6
plt.subplots(figsize=(15,6))

# Using the style bmh for better visualization
plt.style.use('bmh')

# X axis will denote the customer ID, Y axis will denote the number of orders
plt.plot(orders.CustomerID, orders.InvoiceNo)

# Labelling the X axis
plt.xlabel('Customers ID')

# Labelling the Y axis
plt.ylabel('Number of Orders')

#  Title to the plot
plt.title('Number of Orders by different Customers')
plt.show()

# %% [markdown]
# #### We can observe that the highest number of orders is above 7000.

# %% [markdown]
# ### Let's highlight the customers with the highest spent amount:

# %%
#Using groupby function to highlight the Customers with highest spent amount (invoices)

money = dataset1.groupby(by=['CustomerID','Country'], as_index=False)['Amount'].sum()
print('The TOP 5 profitable customers with highest money spent...')
money.sort_values(by='Amount', ascending=False).head()
# Out:
# The TOP 5 profitable customers with highest money spent...
#       CustomerID         Country     Amount
# 1698     14646.0     Netherlands  280206.02
# 4210     18102.0  United Kingdom  259657.30
# 3737     17450.0  United Kingdom  194550.79
# 3017     16446.0  United Kingdom  168472.50
# 1888     14911.0            EIRE  143825.06

# %% [markdown]
# ### The below code will help us to display the money spent by different customers:

# %%
# Creating a subplot of size 15*6
plt.subplots(figsize=(15,6))

# X axis will denote the customer ID, Y axis will denote the amount spent
plt.plot(money.CustomerID, money.Amount)
plt.style.use('bmh')
plt.xlabel('Customers ID')
plt.ylabel('Money spent')
plt.title('Money Spent by different Customers')
plt.show()

# %% [markdown]
# ## Patterns Based on Date and Time:

# %% [markdown]
# ### Let's do some feature engineering. Firstly, we convert the InvoiceDate column to a datetime column.
#
# ### After that, we add year_month, month, day, and hour columns:

# %%
# Convert InvoiceDate from object to datetime
dataset1['InvoiceDate'] = pd.to_datetime(dataset.InvoiceDate, format='%m/%d/%Y %H:%M')

# Creating a new feature called year_month, such that December 2010 will be denoted as 201012
dataset1.insert(loc=2, column='year_month', value=dataset1['InvoiceDate'].map(lambda x: 100*x.year + x.month))

# Creating a new feature for Month
dataset1.insert(loc=3, column='month', value=dataset1.InvoiceDate.dt.month)

# Creating a new feature for Day
# +1 to make Monday=1.....until Sunday=7
dataset1.insert(loc=4, column='day', value=(dataset1.InvoiceDate.dt.dayofweek)+1)

# Creating a new feature for Hour
dataset1.insert(loc=5, column='hour', value=dataset1.InvoiceDate.dt.hour)

# %% [markdown]
# ### Let's plot the number of orders per month:

# %%
plt.style.use('bmh')

# Using groupby to extract No. of Invoices year-monthwise
ax = dataset1.groupby('InvoiceNo')['year_month'].unique().value_counts().sort_index().plot(kind='bar',figsize=(15,6))
ax.set_xlabel('Month',fontsize=15)
ax.set_ylabel('Number of Orders',fontsize=15)
ax.set_title('Number of orders for different Months (Dec 2010 - Dec 2011)',fontsize=15)

# Providing with X tick labels
ax.set_xticklabels(('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','Jun_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11','Dec_11'), rotation='horizontal', fontsize=13)
plt.show()

# %% [markdown]
# ### Let's count the number of invoices per day:

# %%
# Using groupby to count no. of Invoices daywise
ax = dataset1.groupby('InvoiceNo')['day'].unique().value_counts().sort_index().plot(kind='bar',figsize=(15,6))
ax.set_xlabel('Day', fontsize=15)
ax.set_ylabel('Number of Orders', fontsize=15)

# Giving suitable title to the plot
ax.set_title('Number of orders for different Days', fontsize=15)

# Since there are no orders placed on Saturdays, we are excluding Sat from xticklabels
ax.set_xticklabels(('Mon','Tue','Wed','Thur','Fri','Sun'), rotation='horizontal', fontsize=15)
plt.show()

# %% [markdown]
# #### From the above plot, we view the number of orders per day except for Saturday. The highest number of orders is on Thursday.

# %% [markdown]
# ### The number of orders per hour:

# %%
# Using groupby to count the no. of Invoices hourwise
ax = dataset1.groupby('InvoiceNo')['hour'].unique().value_counts().iloc[:-2].sort_index().plot(kind='bar',figsize=(15,6))
ax.set_xlabel('Hour',fontsize=15)
ax.set_ylabel('Number of Orders',fontsize=15)
ax.set_title('Number of orders for different Hours',fontsize=15)

plt.show()

# %% [markdown]
# ### Free Items and Sales:

# %% [markdown]
# ### Now will see how free products affect order volume and how discounts and incentives affect sales:

# %%
dataset1.UnitPrice.describe()
# Out:
# count    397924.000000
# mean          3.116174
# std          22.096788
# min           0.000000
# 25%           1.250000
# 50%           1.950000
# 75%           3.750000
# max        8142.750000
# Name: UnitPrice, dtype: float64

# %% [markdown]
# #### With a minimum unit price equal to 0, there can be either some incorrect entry or free products:

# %%
# checking the distribution of unit price
plt.subplots(figsize=(12,6))

# Using darkgrid style for better visualization
sns.set_style('darkgrid')

# Applying boxplot visualization on Unit Price
sns.boxplot(dataset1.UnitPrice)
plt.show()

# %% [markdown]
# #### Items with UnitPrice of 0 are not outliers; these are the free items.
#
# ### We will create a new dataframe of free products:

# %%
# Creating a new df of free items
freeproducts = dataset1[dataset1['UnitPrice'] == 0]
freeproducts.head()
# Out:
#       InvoiceNo StockCode  year_month  month  day  hour  \
# 9302     537197     22841      201012     12    7    14
# 33576    539263     22580      201012     12    4    14
# 40089    539722     22423      201012     12    2    13
# 47068    540372     22090      201101      1    4    16
# 47070    540372     22553      201101      1    4    16
#
#                         Description  Quantity         InvoiceDate  UnitPrice  \
# 9302   ROUND CAKE TIN VINTAGE GREEN         1 2010-12-05 14:02:00        0.0
# 33576  ADVENT CALENDAR GINGHAM SACK         4 2010-12-16 14:36:00        0.0
# 40089      REGENCY CAKESTAND 3 TIER        10 2010-12-21 13:45:00        0.0
# 47068       PAPER BUNTING RETROSPOT        24 2011-01-06 16:41:00        0.0
# 47070        PLASTERS IN TIN SKULLS        24 2011-01-06 16:41:00        0.0
#
#        CustomerID         Country  Amount
# 9302      12647.0         Germany     0.0
# 33576     16560.0  United Kingdom     0.0
# 40089     14911.0            EIRE     0.0
# 47068     13081.0  United Kingdom     0.0
# 47070     13081.0  United Kingdom     0.0

# %% [markdown]
# ### Let's have a view of the number of free items that were given out year-month wise:

# %%
# Counting how many free items were given out year-month wise
freeproducts.year_month.value_counts()
# Out:
# 201111    14
# 201108     6
# 201012     3
# 201101     3
# 201110     3
# 201103     2
# 201104     2
# 201105     2
# 201107     2
# 201109     2
# 201102     1
# Name: year_month, dtype: int64

# %% [markdown]
# #### We can see that there is at least one free item every month except June 2011.
#
# ### Let's see the frequency of free items for different months:

# %%
# Counting how many free items were given out year-month wise
ax = freeproducts.year_month.value_counts().sort_index().plot(kind='bar',figsize=(12,6))
ax.set_xlabel('Month',fontsize=15)
ax.set_ylabel('Frequency',fontsize=15)
ax.set_title('Frequency for different Months (Dec 2010 - Dec 2011)',fontsize=15)

plt.show()

# %% [markdown]
# #### November 2011 has the highest frequency. Also, compared to May, sales declined, which means there was a slight effect of nonfree items on the number of orders.

# %% [markdown]
# ### Most sold items based on quantity:

# %%
# Creating a new pivot table which sums the Quantity ordered for each item
most_sold= dataset1.pivot_table(index=['StockCode','Description'], values='Quantity', aggfunc='sum').sort_values(by='Quantity', ascending=False)
most_sold.reset_index(inplace=True)
sns.set_style('white')

# Creating a bar plot of Description ( or the item ) on the Y axis and the sum of Quantity on the X axis
# We are plotting only the 10 most ordered items
sns.barplot(y='Description', x='Quantity', data=most_sold.head(10))
plt.title('Top 10 Items based on No. of Sales', fontsize=14)
plt.ylabel('Item')
# Out:
# Text(0, 0.5, 'Item')

# %% [markdown]
# #### From the above plot, we can view the top 10 items based on the number of sales.
#
# ### We will examine how many items were bought by the most number of customers:

# %%
# choosing WHITE HANGING HEART T-LIGHT HOLDER as a sample
d_white = dataset1[dataset1['Description']=='WHITE HANGING HEART T-LIGHT HOLDER']

# %%
# WHITE HANGING HEART T-LIGHT HOLDER has been ordered 2028 times
d_white.shape
# Out:
# (2028, 13)

# %%
# WHITE HANGING HEART T-LIGHT HOLDER has been ordered by 856 customers
len(d_white.CustomerID.unique())
# Out:
# 856

# %%
# Creating a pivot table that displays the sum of unique Customers who bought particular item

most_customers = dataset1.pivot_table(index=['StockCode','Description'], values='CustomerID', aggfunc=lambda x: len(x.unique())).sort_values(by='CustomerID', ascending=False)
most_customers
# Since the count for WHITE HANGING HEART T-LIGHT HOLDER matches above length 856, the pivot table looks correct for all items
# Out:
#                                                CustomerID
# StockCode Description
# 22423     REGENCY CAKESTAND 3 TIER                    881
# 85123A    WHITE HANGING HEART T-LIGHT HOLDER          856
# 47566     PARTY BUNTING                               708
# 84879     ASSORTED COLOUR BIRD ORNAMENT               678
# 22720     SET OF 3 CAKE TINS PANTRY DESIGN            640
# ...                                                   ...
# 35916B    BLUE FELT HANGING HEART WITH FLOWER           1
# 90036F    FLOWER GLASS GARLD NECKL36"TURQUOIS           1
# 90037B    TINY CRYSTAL BRACELET GREEN                   1
# 90038A    GLASS AND PAINTED BEADS BRACELET TO           1
# 23253     16 PC CUTLERY SET PANTRY DESIGN               1
#
# [3897 rows x 1 columns]

# %%
most_customers.reset_index(inplace=True)
sns.set_style('white')

# Creating a bar plot of Description ( or the item ) on the Y axis and the sum of unique Customers on the X axis
# We are plotting only the 10 most bought items
sns.barplot(y='Description', x='CustomerID', data=most_customers.head(10))

# Giving suitable title to the plot
plt.title('Top 10 Items bought by Most no. of Customers', fontsize=14)
plt.ylabel('Item')
# Out:
# Text(0, 0.5, 'Item')

# %% [markdown]
# #### From the above plot, we can view the top items bought by the most number of customers.
#
# ### Let's define our first five choices of items:

# %%
dataset1['items'] = dataset1['Description'].str.replace(' ', '_')

# Storing all the invoice numbers into a list y
y = dataset1['InvoiceNo']
y = y.to_list()

# Using set function to find unique invoice numbers only and storing them in invoices list
invoices = list(set(y))

# Creating empty list first_choices
firstchoices = []

# looping into list of unique invoice numbers
for i in invoices:
    
    # the first item (index = 0) of every invoice is the first purchase
    # extracting the item name for the first purchase
    firstpurchase = dataset1[dataset1['InvoiceNo']==i]['items'].reset_index(drop=True)[0]
    
    # Appending the first purchase name into first choices list
    firstchoices.append(firstpurchase)
    
firstchoices[:5]
# Out:
# ['SET_OF_4_KNICK_KNACK_TINS_DOILEY_',
#  'RED_POLKADOT_BEAKER_',
#  'SET_OF_TEA_COFFEE_SUGAR_TINS_PANTRY',
#  'VINTAGE_KITCHEN_PRINT_PUDDINGS',
#  'SCANDINAVIAN_PAISLEY_PICNIC_BAG']

# %% [markdown]
# ### Now, we will count repeating first choices:

# %%
# Using counter to count repeating first choices
count = Counter(firstchoices)

# Storing the counter into a datafrane
data_first_choices = pd.DataFrame.from_dict(count, orient='index').reset_index()

# Rename columns as item and count
data_first_choices.rename(columns={'index':'item', 0:'count'},inplace=True)

# Sorting the data based on count
data_first_choices.sort_values(by='count',ascending=False)
# Out:
#                                      item  count
# 33               REGENCY_CAKESTAND_3_TIER    203
# 7      WHITE_HANGING_HEART_T-LIGHT_HOLDER    181
# 35                     RABBIT_NIGHT_LIGHT    155
# 17                          PARTY_BUNTING    122
# 390                                Manual    119
# ...                                   ...    ...
# 1935           SQUARE_MINI_PORTRAIT_FRAME      1
# 1936  SWALLOW_WOODEN_CHRISTMAS_DECORATION      1
# 1937         AMBER_GLASS_TASSLE_BAG_CHARM      1
# 1942            RED_RETROSPOT_LUGGAGE_TAG      1
# 2634        WHITE_3_FRAME_BIRDS_AND_TREE_      1
#
# [2635 rows x 2 columns]

# %% [markdown]
# ### We can display our ten first choices of product.

# %%
plt.subplots(figsize=(20,10))
sns.set_style('white')
# Creating a bar plot that displays Item name on the Y axis and Count on the X axis
sns.barplot(y='item', x='count', data=data_first_choices.sort_values(by='count',ascending=False).head(10))
plt.title('Top 10 First Choices', fontsize=14)
plt.ylabel('Item')
# Out:
# Text(0, 0.5, 'Item')

# %% [markdown]
# ### We will use the groupby() function to create a basket that specifies if an item is present in a particular invoice number.We will get the quantity present in the specific invoice number, which must be fixed.
#
# ### Note that this is for all items and invoices:

# %%
basket = (dataset1.groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))
basket.head(10)
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                  0.0                             0.0
# 536366                                  0.0                             0.0
# 536367                                  0.0                             0.0
# 536368                                  0.0                             0.0
# 536369                                  0.0                             0.0
# 536370                                  0.0                             0.0
# 536371                                  0.0                             0.0
# 536372                                  0.0                             0.0
# 536373                                  0.0                             0.0
# 536374                                  0.0                             0.0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                      0.0                           0.0
# 536366                      0.0                           0.0
# 536367                      0.0                           0.0
# 536368                      0.0                           0.0
# 536369                      0.0                           0.0
# 536370                      0.0                           0.0
# 536371                      0.0                           0.0
# 536372                      0.0                           0.0
# 536373                      0.0                           0.0
# 536374                      0.0                           0.0
#
# Description   I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536365                                0.0                       0.0
# 536366                                0.0                       0.0
# 536367                                0.0                       0.0
# 536368                                0.0                       0.0
# 536369                                0.0                       0.0
# 536370                                0.0                       0.0
# 536371                                0.0                       0.0
# 536372                                0.0                       0.0
# 536373                                0.0                       0.0
# 536374                                0.0                       0.0
#
# Description   OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536365                               0.0                       0.0
# 536366                               0.0                       0.0
# 536367                               0.0                       0.0
# 536368                               0.0                       0.0
# 536369                               0.0                       0.0
# 536370                               0.0                       0.0
# 536371                               0.0                       0.0
# 536372                               0.0                       0.0
# 536373                               0.0                       0.0
# 536374                               0.0                       0.0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  ...  \
# InvoiceNo                                                               ...
# 536365                                    0.0                      0.0  ...
# 536366                                    0.0                      0.0  ...
# 536367                                    0.0                      0.0  ...
# 536368                                    0.0                      0.0  ...
# 536369                                    0.0                      0.0  ...
# 536370                                   24.0                      0.0  ...
# 536371                                    0.0                      0.0  ...
# 536372                                    0.0                      0.0  ...
# 536373                                    0.0                      0.0  ...
# 536374                                    0.0                      0.0  ...
#
# Description  ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# InvoiceNo
# 536365                             0.0                        0.0
# 536366                             0.0                        0.0
# 536367                             0.0                        0.0
# 536368                             0.0                        0.0
# 536369                             0.0                        0.0
# 536370                             0.0                        0.0
# 536371                             0.0                        0.0
# 536372                             0.0                        0.0
# 536373                             0.0                        0.0
# 536374                             0.0                        0.0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536365                                    0.0                             0.0
# 536366                                    0.0                             0.0
# 536367                                    0.0                             0.0
# 536368                                    0.0                             0.0
# 536369                                    0.0                             0.0
# 536370                                    0.0                             0.0
# 536371                                    0.0                             0.0
# 536372                                    0.0                             0.0
# 536373                                    0.0                             0.0
# 536374                                    0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536365                                   0.0                              0.0
# 536366                                   0.0                              0.0
# 536367                                   0.0                              0.0
# 536368                                   0.0                              0.0
# 536369                                   0.0                              0.0
# 536370                                   0.0                              0.0
# 536371                                   0.0                              0.0
# 536372                                   0.0                              0.0
# 536373                                   0.0                              0.0
# 536374                                   0.0                              0.0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# InvoiceNo
# 536365                                  0.0                               0.0
# 536366                                  0.0                               0.0
# 536367                                  0.0                               0.0
# 536368                                  0.0                               0.0
# 536369                                  0.0                               0.0
# 536370                                  0.0                               0.0
# 536371                                  0.0                               0.0
# 536372                                  0.0                               0.0
# 536373                                  0.0                               0.0
# 536374                                  0.0                               0.0
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# InvoiceNo
# 536365                               0.0                               0.0
# 536366                               0.0                               0.0
# 536367                               0.0                               0.0
# 536368                               0.0                               0.0
# 536369                               0.0                               0.0
# 536370                               0.0                               0.0
# 536371                               0.0                               0.0
# 536372                               0.0                               0.0
# 536373                               0.0                               0.0
# 536374                               0.0                               0.0
#
# [10 rows x 3877 columns]

# %% [markdown]
# ### We want to know if that particular item is purchased or not. So, we encode units as 1 if purchased or 0 if not.

# %%
def encode_u(x):
  if x < 1:
    return 0
  else:
    return 1


# everything is encoded into 0 and 1
basket = basket.applymap(encode_u)
basket.head(10)
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                    0                               0
# 536366                                    0                               0
# 536367                                    0                               0
# 536368                                    0                               0
# 536369                                    0                               0
# 536370                                    0                               0
# 536371                                    0                               0
# 536372                                    0                               0
# 536373                                    0                               0
# 536374                                    0                               0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                        0                             0
# 536366                        0                             0
# 536367                        0                             0
# 536368                        0                             0
# 536369                        0                             0
# 536370                        0                             0
# 536371                        0                             0
# 536372                        0                             0
# 536373                        0                             0
# 536374                        0                             0
#
# Description   I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536365                                  0                         0
# 536366                                  0                         0
# 536367                                  0                         0
# 536368                                  0                         0
# 536369                                  0                         0
# 536370                                  0                         0
# 536371                                  0                         0
# 536372                                  0                         0
# 536373                                  0                         0
# 536374                                  0                         0
#
# Description   OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536365                                 0                         0
# 536366                                 0                         0
# 536367                                 0                         0
# 536368                                 0                         0
# 536369                                 0                         0
# 536370                                 0                         0
# 536371                                 0                         0
# 536372                                 0                         0
# 536373                                 0                         0
# 536374                                 0                         0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  ...  \
# InvoiceNo                                                               ...
# 536365                                      0                        0  ...
# 536366                                      0                        0  ...
# 536367                                      0                        0  ...
# 536368                                      0                        0  ...
# 536369                                      0                        0  ...
# 536370                                      1                        0  ...
# 536371                                      0                        0  ...
# 536372                                      0                        0  ...
# 536373                                      0                        0  ...
# 536374                                      0                        0  ...
#
# Description  ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# InvoiceNo
# 536365                               0                          0
# 536366                               0                          0
# 536367                               0                          0
# 536368                               0                          0
# 536369                               0                          0
# 536370                               0                          0
# 536371                               0                          0
# 536372                               0                          0
# 536373                               0                          0
# 536374                               0                          0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536365                                      0                               0
# 536366                                      0                               0
# 536367                                      0                               0
# 536368                                      0                               0
# 536369                                      0                               0
# 536370                                      0                               0
# 536371                                      0                               0
# 536372                                      0                               0
# 536373                                      0                               0
# 536374                                      0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536365                                     0                                0
# 536366                                     0                                0
# 536367                                     0                                0
# 536368                                     0                                0
# 536369                                     0                                0
# 536370                                     0                                0
# 536371                                     0                                0
# 536372                                     0                                0
# 536373                                     0                                0
# 536374                                     0                                0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# InvoiceNo
# 536365                                    0                                 0
# 536366                                    0                                 0
# 536367                                    0                                 0
# 536368                                    0                                 0
# 536369                                    0                                 0
# 536370                                    0                                 0
# 536371                                    0                                 0
# 536372                                    0                                 0
# 536373                                    0                                 0
# 536374                                    0                                 0
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# InvoiceNo
# 536365                                 0                                 0
# 536366                                 0                                 0
# 536367                                 0                                 0
# 536368                                 0                                 0
# 536369                                 0                                 0
# 536370                                 0                                 0
# 536371                                 0                                 0
# 536372                                 0                                 0
# 536373                                 0                                 0
# 536374                                 0                                 0
#
# [10 rows x 3877 columns]

# %% [markdown]
# ## 2) MACHINE LEARNING:

# %% [markdown]
# ## Apriori Algorithm :

# %% [markdown]
# ### apriori() function returns a list of items with at least 15% support.
#
# ### association_rules() function returns frequent itemsets only if the level of lift score > 1(min_threshold=1).
#
# ### sort_values() function sorts the data frame in descending order of passed columns (lift and support).

# %%
# trying out on a sample item
wooden_star = basket.loc[basket['WOODEN STAR CHRISTMAS SCANDINAVIAN']==1]

# Using apriori algorithm, creating association rules for the sample item
# Applying apriori algorithm for wooden_star
frequentitemsets = apriori(wooden_star, min_support=0.15, use_colnames=True)

# Storing the association rules into rules
wooden_star_rules = association_rules(frequentitemsets, metric="lift", min_threshold=1)

# Sorting the rules on lift and support
wooden_star_rules.sort_values(['lift','support'],ascending=False).reset_index(drop=True)
# Out:
# C:\software alif\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:115: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
#                                           antecedents  \
# 0                (WOODEN TREE CHRISTMAS SCANDINAVIAN)
# 1               (WOODEN HEART CHRISTMAS SCANDINAVIAN)
# 2   (WOODEN TREE CHRISTMAS SCANDINAVIAN, WOODEN ST...
# 3   (WOODEN HEART CHRISTMAS SCANDINAVIAN, WOODEN S...
# 4                (WOODEN TREE CHRISTMAS SCANDINAVIAN)
# 5               (WOODEN HEART CHRISTMAS SCANDINAVIAN)
# 6                   (PAPER CHAIN KIT 50'S CHRISTMAS )
# 7               (WOODEN HEART CHRISTMAS SCANDINAVIAN)
# 8   (PAPER CHAIN KIT 50'S CHRISTMAS , WOODEN STAR ...
# 9   (WOODEN HEART CHRISTMAS SCANDINAVIAN, WOODEN S...
# 10                  (PAPER CHAIN KIT 50'S CHRISTMAS )
# 11              (WOODEN HEART CHRISTMAS SCANDINAVIAN)
# 12              (WOODEN HEART CHRISTMAS SCANDINAVIAN)
# 13                (SET OF 3 WOODEN HEART DECORATIONS)
# 14  (WOODEN HEART CHRISTMAS SCANDINAVIAN, WOODEN S...
# 15  (WOODEN STAR CHRISTMAS SCANDINAVIAN, SET OF 3 ...
# 16              (WOODEN HEART CHRISTMAS SCANDINAVIAN)
# 17                (SET OF 3 WOODEN HEART DECORATIONS)
# 18               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 19              (WOODEN HEART CHRISTMAS SCANDINAVIAN)
# 20               (WOODEN TREE CHRISTMAS SCANDINAVIAN)
# 21               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 22  (WOODEN TREE CHRISTMAS SCANDINAVIAN, WOODEN HE...
# 23               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 24                  (PAPER CHAIN KIT 50'S CHRISTMAS )
# 25               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 26               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 27                (SET OF 3 WOODEN HEART DECORATIONS)
# 28               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 29              (SET OF 3 WOODEN STOCKING DECORATION)
# 30               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 31                 (SET OF 3 WOODEN TREE DECORATIONS)
# 32  (PAPER CHAIN KIT 50'S CHRISTMAS , WOODEN HEART...
# 33               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 34               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 35               (WHITE HANGING HEART T-LIGHT HOLDER)
# 36               (SET OF 3 WOODEN SLEIGH DECORATIONS)
# 37               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 38                        (ZINC FOLKART SLEIGH BELLS)
# 39               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
# 40  (WOODEN HEART CHRISTMAS SCANDINAVIAN, SET OF 3...
# 41               (WOODEN STAR CHRISTMAS SCANDINAVIAN)
#
#                                           consequents  antecedent support  \
# 0               (WOODEN HEART CHRISTMAS SCANDINAVIAN)            0.521940
# 1                (WOODEN TREE CHRISTMAS SCANDINAVIAN)            0.736721
# 2               (WOODEN HEART CHRISTMAS SCANDINAVIAN)            0.521940
# 3                (WOODEN TREE CHRISTMAS SCANDINAVIAN)            0.736721
# 4   (WOODEN HEART CHRISTMAS SCANDINAVIAN, WOODEN S...            0.521940
# 5   (WOODEN TREE CHRISTMAS SCANDINAVIAN, WOODEN ST...            0.736721
# 6               (WOODEN HEART CHRISTMAS SCANDINAVIAN)            0.221709
# 7                   (PAPER CHAIN KIT 50'S CHRISTMAS )            0.736721
# 8               (WOODEN HEART CHRISTMAS SCANDINAVIAN)            0.221709
# 9                   (PAPER CHAIN KIT 50'S CHRISTMAS )            0.736721
# 10  (WOODEN HEART CHRISTMAS SCANDINAVIAN, WOODEN S...            0.221709
# 11  (PAPER CHAIN KIT 50'S CHRISTMAS , WOODEN STAR ...            0.736721
# 12                (SET OF 3 WOODEN HEART DECORATIONS)            0.736721
# 13              (WOODEN HEART CHRISTMAS SCANDINAVIAN)            0.198614
# 14                (SET OF 3 WOODEN HEART DECORATIONS)            0.736721
# 15              (WOODEN HEART CHRISTMAS SCANDINAVIAN)            0.198614
# 16  (WOODEN STAR CHRISTMAS SCANDINAVIAN, SET OF 3 ...            0.736721
# 17  (WOODEN HEART CHRISTMAS SCANDINAVIAN, WOODEN S...            0.198614
# 18              (WOODEN HEART CHRISTMAS SCANDINAVIAN)            1.000000
# 19               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.736721
# 20               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.521940
# 21               (WOODEN TREE CHRISTMAS SCANDINAVIAN)            1.000000
# 22               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.420323
# 23  (WOODEN TREE CHRISTMAS SCANDINAVIAN, WOODEN HE...            1.000000
# 24               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.221709
# 25                  (PAPER CHAIN KIT 50'S CHRISTMAS )            1.000000
# 26                (SET OF 3 WOODEN HEART DECORATIONS)            1.000000
# 27               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.198614
# 28              (SET OF 3 WOODEN STOCKING DECORATION)            1.000000
# 29               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.182448
# 30                 (SET OF 3 WOODEN TREE DECORATIONS)            1.000000
# 31               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.182448
# 32               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.177829
# 33  (PAPER CHAIN KIT 50'S CHRISTMAS , WOODEN HEART...            1.000000
# 34               (WHITE HANGING HEART T-LIGHT HOLDER)            1.000000
# 35               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.170901
# 36               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.163972
# 37               (SET OF 3 WOODEN SLEIGH DECORATIONS)            1.000000
# 38               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.163972
# 39                        (ZINC FOLKART SLEIGH BELLS)            1.000000
# 40               (WOODEN STAR CHRISTMAS SCANDINAVIAN)            0.152425
# 41  (WOODEN HEART CHRISTMAS SCANDINAVIAN, SET OF 3...            1.000000
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.736721  0.420323    0.805310  1.093101  0.035799    1.352299
# 1             0.521940  0.420323    0.570533  1.093101  0.035799    1.113147
# 2             0.736721  0.420323    0.805310  1.093101  0.035799    1.352299
# 3             0.521940  0.420323    0.570533  1.093101  0.035799    1.113147
# 4             0.736721  0.420323    0.805310  1.093101  0.035799    1.352299
# 5             0.521940  0.420323    0.570533  1.093101  0.035799    1.113147
# 6             0.736721  0.177829    0.802083  1.088721  0.014492    1.330254
# 7             0.221709  0.177829    0.241379  1.088721  0.014492    1.025929
# 8             0.736721  0.177829    0.802083  1.088721  0.014492    1.330254
# 9             0.221709  0.177829    0.241379  1.088721  0.014492    1.025929
# 10            0.736721  0.177829    0.802083  1.088721  0.014492    1.330254
# 11            0.221709  0.177829    0.241379  1.088721  0.014492    1.025929
# 12            0.198614  0.152425    0.206897  1.041700  0.006102    1.010443
# 13            0.736721  0.152425    0.767442  1.041700  0.006102    1.132102
# 14            0.198614  0.152425    0.206897  1.041700  0.006102    1.010443
# 15            0.736721  0.152425    0.767442  1.041700  0.006102    1.132102
# 16            0.198614  0.152425    0.206897  1.041700  0.006102    1.010443
# 17            0.736721  0.152425    0.767442  1.041700  0.006102    1.132102
# 18            0.736721  0.736721    0.736721  1.000000  0.000000    1.000000
# 19            1.000000  0.736721    1.000000  1.000000  0.000000         inf
# 20            1.000000  0.521940    1.000000  1.000000  0.000000         inf
# 21            0.521940  0.521940    0.521940  1.000000  0.000000    1.000000
# 22            1.000000  0.420323    1.000000  1.000000  0.000000         inf
# 23            0.420323  0.420323    0.420323  1.000000  0.000000    1.000000
# 24            1.000000  0.221709    1.000000  1.000000  0.000000         inf
# 25            0.221709  0.221709    0.221709  1.000000  0.000000    1.000000
# 26            0.198614  0.198614    0.198614  1.000000  0.000000    1.000000
# 27            1.000000  0.198614    1.000000  1.000000  0.000000         inf
# 28            0.182448  0.182448    0.182448  1.000000  0.000000    1.000000
# 29            1.000000  0.182448    1.000000  1.000000  0.000000         inf
# 30            0.182448  0.182448    0.182448  1.000000  0.000000    1.000000
# 31            1.000000  0.182448    1.000000  1.000000  0.000000         inf
# 32            1.000000  0.177829    1.000000  1.000000  0.000000         inf
# 33            0.177829  0.177829    0.177829  1.000000  0.000000    1.000000
# 34            0.170901  0.170901    0.170901  1.000000  0.000000    1.000000
# 35            1.000000  0.170901    1.000000  1.000000  0.000000         inf
# 36            1.000000  0.163972    1.000000  1.000000  0.000000         inf
# 37            0.163972  0.163972    0.163972  1.000000  0.000000    1.000000
# 38            1.000000  0.163972    1.000000  1.000000  0.000000         inf
# 39            0.163972  0.163972    0.163972  1.000000  0.000000    1.000000
# 40            1.000000  0.152425    1.000000  1.000000  0.000000         inf
# 41            0.152425  0.152425    0.152425  1.000000  0.000000    1.000000

# %% [markdown]
# ### Now, we will create the function in which we pass an item name, and it returns the items that are frequently bought together:

# %%
# In other words, it returns the items which are likely to be bought by user because he bought the item passed into function
def frequently_bought_t(item):
    # df of item passed
    item_d = basket.loc[basket[item]==1]
    
    # Applying apriori algorithm on item df
    frequentitemsets = apriori(item_d, min_support=0.15, use_colnames=True)
    
    # Storing association rules
    rules = association_rules(frequentitemsets, metric="lift", min_threshold=1)
    
    # Sorting on lift and support
    rules.sort_values(['lift','support'],ascending=False).reset_index(drop=True)
    print('Items frequently bought together with {0}'.format(item))
    
    # Returning top 6 items with highest lift and support
    return rules['consequents'].unique()[:6]

# %%
frequently_bought_t('WOODEN STAR CHRISTMAS SCANDINAVIAN')
# Out:
# Items frequently bought together with WOODEN STAR CHRISTMAS SCANDINAVIAN
# C:\software alif\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:115: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
# array([frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN'}),
#        frozenset({"PAPER CHAIN KIT 50'S CHRISTMAS "}),
#        frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN'}),
#        frozenset({'SET OF 3 WOODEN HEART DECORATIONS'}),
#        frozenset({'SET OF 3 WOODEN SLEIGH DECORATIONS'}),
#        frozenset({'SET OF 3 WOODEN STOCKING DECORATION'})], dtype=object)

# %%
frequently_bought_t('JAM MAKING SET WITH JARS')
# Out:
# C:\software alif\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:115: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
# Items frequently bought together with JAM MAKING SET WITH JARS
# array([frozenset({'JAM MAKING SET PRINTED'}),
#        frozenset({'JAM MAKING SET WITH JARS'}),
#        frozenset({'PACK OF 72 RETROSPOT CAKE CASES'}),
#        frozenset({'RECIPE BOX PANTRY YELLOW DESIGN'}),
#        frozenset({'REGENCY CAKESTAND 3 TIER'}),
#        frozenset({'SET OF 3 CAKE TINS PANTRY DESIGN '})], dtype=object)

# %% [markdown]
# #### We can have a view of the items which are commonly purchased together.
